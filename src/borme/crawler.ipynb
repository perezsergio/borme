# %%
from pypdf import PdfReader
from functools import reduce


def get_pages_in_pdf(path_to_pdf: str) -> int:
    """Return the number of pages in a pdf file."""
    reader = PdfReader(path_to_pdf)
    num_of_pages = len(reader.pages)
    return num_of_pages


def read_text_from_pdf(path_to_pdf: str) -> str:
    """Return the text content of a pdf file."""
    reader = PdfReader(path_to_pdf)
    pages_text = [page.extract_text() for page in reader.pages]

    pdf_text = reduce(lambda x, y: x + y, pages_text)
    return pdf_text

# %%
import re
from logs import log_unexpected_num_of_matches


def drop_lines_with_pattern(input_string, pattern, expected_num_of_matches):
    """
    Drop the lines that contain a match to some pattern.
    If the number of lines dropped is not the expected, log it.
    """
    # filter lines that don't contain a match to the pattern
    lines = input_string.split("\n")
    filtered_lines = [line for line in lines if not re.search(pattern, line)]

    # check if the number of matches is not the expected
    num_of_matches = len(lines) - len(filtered_lines)
    if num_of_matches != expected_num_of_matches:
        log_unexpected_num_of_matches(pattern, num_of_matches, expected_num_of_matches)

    # join filtered lines to a single string
    result_string = "\n".join(filtered_lines)

    return result_string


def drop_pattern(input_string, pattern, expected_num_of_matches):
    """
    Substitute the occurrences of the pattern with an empty string.
    If the number of occurrences is not the expected, log it.
    """
    # substitute matches with an empty string
    result_string = re.sub(pattern, "", input_string)

    # check num of matches is the expected number
    num_of_matches = len(re.findall(pattern, input_string))
    if num_of_matches != expected_num_of_matches:
        log_unexpected_num_of_matches(pattern, num_of_matches, expected_num_of_matches)

    return result_string

# %%
def drop_headers_and_footnotes(pdf_text: str, num_of_pages: int) -> str:
    """
    Given the text content of a pdf of the BORME registry,
    use regex patterns to find the headers and footnotes inside of the pdf text,
    drop them.
    """
    # Define pattern, expected_num_of_matches for the filler texts that we want to remove
    final_footnote = (
        "https://www.boe.es BOLETÍN OFICIAL DEL REGISTRO MERCANTIL D.L.",
        1,
    )
    section_header = ("SECCIÓN PRIMERA\n Empresarios\n Actos inscritos\n", 1)
    header = ("BOLETÍN OFICIAL DEL REGISTRO MERCANTIL", num_of_pages)
    subheader = (r"Núm. \d+ [A-Za-z]+ \d+ de [A-Za-z]+ de \d+ Pág. \d+", num_of_pages)
    footnote_1 = (r"cve: BORME-[A-Za-z]-\d+-\d+-\d+", num_of_pages)
    footnote_2 = ("Verificable en https://www.boe.es", num_of_pages)

    # Remove lines that contain the specified patterns
    result_text = pdf_text
    for pattern, expected_num_of_matches in [
        final_footnote,
        header,
        subheader,
        footnote_1,
        footnote_2,
    ]:
        result_text = drop_lines_with_pattern(
            result_text, pattern, expected_num_of_matches
        )

    # Remove occurrences of the specified pattern
    result_text = drop_pattern(result_text, *section_header)

    return result_text.strip()

# %%
def split_text_by_acts(acts_text: str) -> list[str]:
    """
    Given a text from a pdf of the BORME registry,
    containing only the act information with no headers footnotes or region name,
    split text in a list, where each element of the list corresponds to a different act.
    """
    # Pattern: digit at the start of line followed by ' - ' and a word in all uppercase
    pattern = r"(\n\d+ - [A-Z]+)"
    # Split string by pattern, keep the separators.
    # The separators are kept because the pattern is wrapped in parenthesis.
    splitted_text = re.split(pattern, acts_text)
    # remove empty strings from splitted text
    splitted_text = [e for e in splitted_text if e != ""]

    # The splitted text has the form [pattern match, (...), pattern match, (...), ...]
    # we want to add the odd and even elements
    even_els = splitted_text[0::2]
    odd_els = splitted_text[1::2]
    assert len(even_els) == len(odd_els), "num of even and odd elements do not match"
    acts = [even_els[i] + odd_els[i] for i in range(len(even_els))]

    return acts

# %%
def parse_act(act: str, region_name: str) -> dict:
    """
    Parse the string containing the information of a given act,
    return a dictionary with the structured information
    """
    lines = act.strip().split("\n")
    # id, company name are in the 1st line, separated by an '-' character
    id, company_name = lines[0].split("-", 1)
    clean_company_name = company_name.strip().replace(".", "")

    # store the rest of the text in the variable description
    # For more information about this design choice, consult the README
    description = "\n".join(lines[1:])

    return {
        "id": id,
        "company_name": clean_company_name,
        "region_name": region_name,
        "description": description,
    }

# %%
parse_act(acts[0], region_name)
# Out:
# {'id': '505995 ',
#  'company_name': 'PRODUCTOS JAFEP SOCIEDAD LIMITADA',
#  'region_name': 'ALBACETE',
#  'description': 'Nombramientos.  Auditor: EUDITA CUSPIDE AUDITORES SOCIEDAD LIMITADA.  Datos registrales. T 1027, L 791, F 55, S 8, H\nAB 2767, I/A 24 (20.11.23).'}

# %%
path = "../../data/output/2023-11-28/BORME-A-2023-226-02.pdf"
pdf_text = read_text_from_pdf(path)
num_of_pages = get_pages_in_pdf(path)

cleaned_pdf_text = drop_headers_and_footnotes(pdf_text, num_of_pages)

# The first line of the cleaned pdf text is the region name,
# the rest is the text containing the act information
region_name = cleaned_pdf_text.split("\n")[0]
acts_text = cleaned_pdf_text.replace(region_name, "", 1)

acts = split_text_by_acts(acts_text)
cleaned_acts = [parse_act(act, region_name) for act in acts]

# %%
cleaned_acts
# Out:
# [{'id': '505995 ',
#   'company_name': 'PRODUCTOS JAFEP SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Nombramientos.  Auditor: EUDITA CUSPIDE AUDITORES SOCIEDAD LIMITADA.  Datos registrales. T 1027, L 791, F 55, S 8, H\nAB 2767, I/A 24 (20.11.23).'},
#  {'id': '505996 ',
#   'company_name': 'CONSTRUCCIONES LORENZO LINUESA SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 7.11.23. Objeto social: - Las obras de construcción y albañilería en general. - La\ncompraventa de terrenos y urbanización de los mismos. - La promoción y compraventa de locales comerciales, viviendas y\napartamentos. - La explotación en régimen de arrendamiento y la adquisición de bienes inmuebles, así como otras actividade.\nDomicilio: C/ JUAN II, 3 02300 (ALCARAZ). Capital: 5.000,00 Euros.  Declaración de unipersonalidad. Socio único: LORENZO\nLINUESA JUAN. Nombramientos.  Adm. Unico: LORENZO LINUESA JUAN.  Datos registrales. T 1071, L 835, F 47, S 8, H AB\n30345, I/A 1 (20.11.23).'},
#  {'id': '505997 ',
#   'company_name': 'CONSTRUCCIONESTMC DE HELLIN SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 8.11.23. Objeto social: Actividad principal viene constituida por la actividad que tiene por\nobjeto otras actividades de construcción especializada n.c.o.p (CNAE 4399),. Domicilio: AVDA DE CASTILLA LA MANCHA, 4 bajo 2\n02400 (HELLIN). Capital: 3.000,00 Euros.  Declaración de unipersonalidad. Socio único: RUIZ GOMEZ SERGIO. Nombramientos.\nAdm. Unico: RUIZ GOMEZ SERGIO.  Datos registrales. T 1071, L 835, F 50, S 8, H AB 30346, I/A 1 (20.11.23).'},
#  {'id': '505998 ',
#   'company_name': 'ALBAMAOR SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 10.11.23. Objeto social: Comercio al por menor de vehículos terrestres. CNAE 4511. -\nComercio al por menor de accesorios y piezas de recambio para vehículos terrestres. CNAE 4532. - Comercio al por menor de\ncubiertas y cámaras de aire para toda clase de vehículos terrestres. CNAE 4532. - Reparación de vehículos automóviles. Domicilio:\nAVDA GREGORIO ARCOS, 41 02007 (ALBACETE). Capital: 300.000,00 Euros.  Nombramientos.  Adm. Unico: MARTINEZ\nSORIANO JAVIER.  Datos registrales. T 1071, L 835, F 52, S 8, H AB 30347, I/A 1 (21.11.23).'},
#  {'id': '505999 ',
#   'company_name': 'OBRYSEAL JOCAR SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ceses/Dimisiones.  Adm. Solid.: MARTINEZ ESPARCIA OSCAR.  Datos registrales. T 952, L 716, F 150, S 8, H AB 24608, I/A 3\n(20.11.23).'},
#  {'id': '506000 ',
#   'company_name': 'LA CREMA DEL CAFE CASTILLA LA MANCHA SOCIEDAD LIMITADA LABORAL',
#   'region_name': 'ALBACETE',
#   'description': 'Ceses/Dimisiones.  Liquidador: TOMAS CERDAN PEDRO ENRIQUE. Adm. Solid.: TOMAS CERDAN PEDRO ENRIQUE;SANCHEZ\nSORIANO JESUS JAVIER.  Nombramientos.  Liquidador: TOMAS CERDAN PEDRO ENRIQUE.  Disolución.  Voluntaria.  Extinción.\nDatos registrales. T 682, L 446, F 29, S 8, H AB 9378, I/A 3 (20.11.23).'},
#  {'id': '506001 ',
#   'company_name': 'VALDEBUS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ceses/Dimisiones.  Adm. Mancom.: ARCE JIMENEZ TOMAS;ARCE LANDETE JOSE BENITO.  Nombramientos.  Adm. Solid.:\nARCE LANDETE JOSE BENITO;ARCE JIMENEZ TOMAS.  Otros conceptos:  Cambio del Organo de Administración:\nAdministradores mancomunados a Administradores solidarios.  Datos registrales. T 1027, L 791, F 213, S 8, H AB 2163, I/A 10\n(20.11.23).'},
#  {'id': '506002 ',
#   'company_name': 'ABOL INGENIERIA SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Cambio de domicilio social.  C/ ANTONIO GOTOR, 2 7º A 02002 (ALBACETE).  Datos registrales. T 793, L 557, F 223, S 8, H AB\n14487, I/A 3 (20.11.23).'},
#  {'id': '506003 ',
#   'company_name': 'RENOVALIA TRAMONTANA SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Nombramientos.  Consejero: SOLVICHE EMMA LOUISE AMELIE.  Datos registrales. T 1061, L 825, F 204, S 8, H AB 29533, I/A 14\n(20.11.23).'},
#  {'id': '506004 ',
#   'company_name': 'RENOVALIA PV BROWNFIELD SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 170, S 8, H AB 27878, I/A 9'},
#  {'id': '506005 ',
#   'company_name': 'RENOVALIA O&M SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1037, L 801, F 164, S 8, H AB 18033, I/A 24\n(20.11.23).'},
#  {'id': '506006 ',
#   'company_name': 'RENOVALIA SOLAR 3 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1055, L 819, F 91, S 8, H AB 17148, I/A 30\n(20.11.23).'},
#  {'id': '506007 ',
#   'company_name': 'RENOVALIA ENERGY SOCIEDAD ANONIMA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1055, L 819, F 93, S 8, H AB 9865, I/A 49\n(20.11.23).'},
#  {'id': '506008 ',
#   'company_name': 'RENOVALIA SOLAR SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 120, S 8, H AB 16050, I/A 30\n(20.11.23).'},
#  {'id': '506009 ',
#   'company_name': 'RENOVALIA SOLAR 2 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 124, S 8, H AB 17147, I/A 37\n(20.11.23).'},
#  {'id': '506010 ',
#   'company_name': 'RENOVALIA PUERTOLLANO SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 213, S 8, H AB 19470, I/A 16\n(20.11.23).'},
#  {'id': '506011 ',
#   'company_name': 'RENOVALIA SOLAR 5 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 158, S 8, H AB 18180, I/A 14\n(20.11.23).'},
#  {'id': '506012 ',
#   'company_name': 'RENOVALIA SOLAR 6 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 160, S 8, H AB 19058, I/A 16\n(20.11.23).'},
#  {'id': '506013 ',
#   'company_name': 'RENOVALIA SOLAR 7 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1025, L 789, F 93, S 8, H AB 19059, I/A 17\n(20.11.23).'},
#  {'id': '506014 ',
#   'company_name': 'RENOVALIA SOLAR 8 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1033, L 797, F 156, S 8, H AB 17149, I/A 15\n(20.11.23).'},
#  {'id': '506015 ',
#   'company_name': 'RENOVALIA SOLAR 9 SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: ERNST & YOUNG SOCIEDAD LIMITADA.  Datos registrales. T 1055, L 819, F 62, S 8, H AB 19472, I/A 17\n(20.11.23).'},
#  {'id': '506016 ',
#   'company_name': 'SOLUCIONES TECNICAS PAFER SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ampliacion del objeto social.  Fabricación de maquinaria para la industria metalúrgica.  Datos registrales. T 920, L 684, F 137, S 8,\nH AB 18012, I/A 6 (20.11.23).'},
#  {'id': '506017 ',
#   'company_name': 'GESTORIA JIMENEZ MARTINEZ SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Adm. Mancom.: GIMENEZ MARTINEZ SALUSTIANO;JIMENEZ JIMENEZ SALUSTIANO;JIMENEZ JIMENEZ JUSTO.\nModificaciones estatutarias.  "ARTICULO 15.. ADMINISTRADORES.- La Junta General confiará laAdministración a un Administrador\núnico, varios solidarios, con un máximo de cinco, a un Consejo de Administración, o a tres mancomunados, quienes ejercerán dichos\ncargos, mancomunadamente dos cualesquiera de los tres administradores nombrados.  Datos registrales. T 744, L 508, F 51, S 8, H\nAB 11920, I/A 3 (20.11.23).'},
#  {'id': '506018 ',
#   'company_name': 'INDUSTRIAS QUIMICAS DEL MAGNESIO SOCIEDAD ANONIMA',
#   'region_name': 'ALBACETE',
#   'description': 'Nombramientos.  Auditor: CASAMITJANA E IBORRA AUDITORES SOCIEDAD LIMITADA P.  Datos registrales. T 546, L 310, F 224,\nS 8, H AB 1648, I/A 10 (20.11.23).'},
#  {'id': '506019 ',
#   'company_name': 'GRUPO IDENTIDAD Y PUBLICIDAD SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ceses/Dimisiones.  Liquidador: HINAREJOS MARTINEZ JOAQUINA MARIA. Adm. Unico: HINAREJOS MARTINEZ JOAQUINA\nMARIA.  Revocaciones.  Apoderado: ROBLES MAGAN JUAN CARLOS.  Nombramientos.  Liquidador: HINAREJOS MARTINEZ'},
#  {'id': '506020 ',
#   'company_name': 'ECOBIOMASA JUMP MINERAL SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ampliación de capital.  Capital: 20.000,00 Euros. Resultante Suscrito: 60.000,00 Euros.  Datos registrales. T 1028, L 792, F 3, S 8,\nH AB 28601, I/A 4 (21.11.23).'},
#  {'id': '506021 ',
#   'company_name': 'INPROVE VENTAS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Sociedad unipersonal. Cambio de identidad del socio único: FELGUERA GARCIA MARIA DEL MAR. Ceses/Dimisiones.  Adm.\nUnico: CASTILLO MARTINEZ FRANCISCO.  Nombramientos.  Adm. Unico: FELGUERA GARCIA MARIA DEL MAR.  Datos\nregistrales. T 1041, L 805, F 79, S 8, H AB 29215, I/A 2 (21.11.23).'},
#  {'id': '506022 ',
#   'company_name': 'INPROVE VENTAS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Otros conceptos:  EXPEDIDA Certificación de todos los asientos referentes a la mercantil de ésta hoja, como consecuencia de su\ntraslado de Domicilio a la Provincia de CIUDAD REAL; habiéndose extendido diligencia de CIERRE PROVISIONAL por plazo de seis\nmeses, de conformidad con lo establecido en el Artículo 19 del Reglamento del Registro Mercantil.  Datos registrales. T 1041, L 805,\nF 79, S 8, H AB 29215, I/ADILIG (21.11.23).'},
#  {'id': '506023 ',
#   'company_name': 'HISPANO AMERICANA DE RESTAURACION Y EVENTOS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 10.11.23. Objeto social: Actividad principal: La explotación, gestión, comercialización y\ndesarrollo de las actividades propias de la hostelería y la restauración en general. CNAE. 56.10. Otras Actividades: La preparación,\nconservación, servicio y venta, incluso a domicilio, de todo tipo de comidas, bebidas, postres y dulce. Domicilio: C/ MUELLE, 16 3º\nDcha 02001 (ALBACETE). Capital: 10.000,00 Euros.  Declaración de unipersonalidad. Socio único: OVIEDO GARCIA MARLENIS.\nNombramientos.  Adm. Unico: OVIEDO GARCIA MARLENIS.  Datos registrales. T 1071, L 835, F 61, S 8, H AB 30348, I/A 1\n(21.11.23).'},
#  {'id': '506024 ',
#   'company_name': 'ROSILLO Y ALABORT SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': "Otros conceptos:  Declarar al ejecutado Rosillo y Alabort Sociedad Limitada, en situación de INSOLVENCIA TOTAL, por importe de\n36.269'83 euros, insolvencia que se entenderá a todos los efectos como provisionial.  Datos registrales. T 972, L 736, F 105, S 8, H\nAB 25541, I/A 2 (21.11.23)."},
#  {'id': '506025 ',
#   'company_name': 'REHABITALIA ALBACETE SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': "Otros conceptos:  Declarar al ejecutado Rehabilitalia Albacete Sociedad Limitada, en situación de INSOLVENCIA TOTAL, por importe\nde 2.682'82 euros, insolvencia que se entenderá a todos los efectos como provisionial.  Datos registrales. T 968, L 732, F 91, S 8, H\nAB 25215, I/A 4 (21.11.23)."},
#  {'id': '506026 ',
#   'company_name': 'SISTAFIL SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': "Otros conceptos:  Declarar al ejecutado Sistafil Sociedad Limitada, en situación de INSOLVENCIA TOTAL, por importe de 2.789'81\neuros, insolvencia que se entenderá a todos los efectos como provisionial.  Datos registrales. T 983, L 747, F 144, S 8, H AB 26164,\nI/A 2 (21.11.23)."},
#  {'id': '506027 ',
#   'company_name': 'UMABURGER SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 14.11.23. Objeto social: La explotación, gestión, comercialización y desarrollo de\nactividades propias de la hostelería, la restauración y el turismo. La fabricación, importación, exportación, la intermediación,\nasesoramiento y el comercio al por mayor y por menor de máquinas, elementos y material relacionado con energías a. Domicilio: C/\nGAONA, 22 8º A 02001 (ALBACETE). Capital: 3.000,00 Euros.  Declaración de unipersonalidad. Socio único: LOPEZ BLEDA\nCARRO DAVID. Nombramientos.  Adm. Unico: LOPEZ BLEDA CARRO DAVID.  Datos registrales. T 1071, L 835, F 62, S 8, H AB\n30349, I/A 1 (21.11.23).'},
#  {'id': '506028 ',
#   'company_name': 'HORMAL FABRICA DE HORMAS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Situación concursal.  Procedimiento concursal 4/2023. FIRME: SI, Fecha de resolución 30/03/2023. Auto de declaración de concurso.\nVoluntario. Juzgado: num. 0 JUZGADO DE LO MERCANTIL NUMERO 1 DE ALBACETE. Juez: EVA MARTINEZ CUENCA.\nResoluciones: 1.- Declarar en estado de CONCURSO SIN MASA a la entidadHORMAL FABRICA DE HORMAS S.L.U. con CIF\nB02494037. 2.- El pasivo que resulta de la documentación presentada por la deudora asciende a la cantidad 74.749,72 Euros. 3.-\nProcédase a la remisión telemática al Boletín Oficial delEstado para su.  Situación concursal.  Procedimiento concursal 4/2023.\nFIRME: SI, Fecha de resolución 30/03/2023. Resoluciones acordando la intervención o suspensión de las factultades de administración\ny disposición del concursado. Juzgado: num. 0 JUZGADO DE LO MERCANTIL NUMERO 1 DE ALBACETE. Juez: EVA MARTINEZ\nCUENCA. Resoluciones: 1.- Declarar en estado de CONCURSO SIN MASA a la entidadHORMAL FABRICA DE HORMAS S.L.U. con\nCIF B02494037. 2.- El pasivo que resulta de la documentación presentada por la deudora asciende a la cantidad 74.749,72 Euros. 3.-\nProcédase a la remisión telemática al Boletín Oficial delEstado para su.  Datos registrales. T 1011, L 775, F 33, S 8, H AB 20981, I/A\n5 (21.11.23).'},
#  {'id': '506029 ',
#   'company_name': 'HORMAL FABRICA DE HORMAS SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Ceses/Dimisiones.  Adm. Unico: AGUADO RICO DESIDERIA.  Cierre provisional hoja registral Art.485 TRLC. Insuficiencia de\nmasa activa. Situación concursal.  Procedimiento concursal 4/2023. FIRME: SI, Fecha de resolución 30/03/2023. Auto de conclusión\ndel concurso. Insuficiencia de la masa activa. Juzgado: num. 0 JUZGADO DE LO MERCANTIL NUMERO 1 DE ALBACETE. Juez: EVA\nB02494037, por insuficiencia de masa activa para satisfacer los créditos contra la masa, así como el archivo de las actuaciones. 2.- Se\nacuerda el cierre provisional de la hoja abierta.  Datos registrales. T 1011, L 775, F 33, S 8, H AB 20981, I/A 6 (21.11.23).'},
#  {'id': '506030 ',
#   'company_name': 'SERVIÑAMALEA SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Constitución.  Comienzo de operaciones: 15.11.23. Objeto social: la agricultura y la prestación de servicios agrícolas y el alquiler de\nmaquinaria agrícola. CNAE PRINCIPAL: 0161: actividades de apoyo a la agricultura. CNAE 7731: alquiler de maquinaria y equipo de\nuso agrícola. Domicilio: PASEO DELICIAS, 6 02270 (VILLAMALEA). Capital: 20.000,00 Euros.  Nombramientos.  Adm. Unico: SAEZ\nCUTANDA ROCIO.  Datos registrales. T 1071, L 835, F 67, S 8, H AB 30350, I/A 1 (21.11.23).'},
#  {'id': '506031 ',
#   'company_name': 'PACINO POWER INTERNATIONAL SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: PRICEWATERHOUSECOOPERS AUDITORES SOCIEDAD LIMITADA.  Datos registrales. T 1028, L 792, F\n137, S 8, H AB 17974, I/A 32 (21.11.23).'},
#  {'id': '506032 ',
#   'company_name': 'TRANSPORTES OJE-CHAR SOCIEDAD LIMITADA',
#   'region_name': 'ALBACETE',
#   'description': 'Reelecciones.  Auditor: AUDISERVICIOS AUDITORES CONSULTORES SOCIEDAD LIMIT.  Datos registrales. T 1013, L 777, F 194,\nS 8, H AB 6962, I/A 13 (21.11.23).'}]

# %%
x = [0, 1, 2, 3, 4, 5]
even_els = x[0::2]
odd_els = x[1::2]
[x + y for x in even_els for y in odd_els]
# Out:
# [1, 3, 5, 3, 5, 7, 5, 7, 9]
